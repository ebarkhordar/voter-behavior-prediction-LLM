# %%
# !pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.30.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.2)

# %%
import os
import json
import pandas as pd
import numpy as np

from datetime import datetime
from openai import OpenAI

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/voter-behavior-prediction-LLM/
# Out:
# /content/drive/MyDrive/voter-behavior-prediction-LLM

# %%
# Constants
SAMPLE_SIZE = 90
RANDOM_STATE = 42
ENV_FILE_PATH = '.env'

# %%
def load_env_variables(file_path):
    """Load key-value pairs from a .env file and set them as environment variables."""
    with open(file_path, 'r') as file:
        for line in file:
            line = line.strip()
            if line and not line.startswith('#'):
                key, value = line.split('=', 1)
                os.environ[key] = value

load_env_variables(ENV_FILE_PATH)

# %%
# Function to load city codes from a file into a dictionary
def load_city_codes(file_path):
    city_codes = {}
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            code, name = line.strip().split(':')
            city_codes[int(code)] = name
    return city_codes

# Load city codes from the file
file_path = 'city_codes.txt'
city_mapping = load_city_codes(file_path)

# %%
# Load survey data
df_survey_data = pd.read_excel('survey.xlsx')
print("Survey data loaded successfully.")
# Out:
# Survey data loaded successfully.

# %%
# Preprocess the data
# 1) Convert float to integer for 'Age' column
df_survey_data['Age_EN'] = df_survey_data['Age_survey'].fillna(0).astype(int)

# 2) Map education levels to desired strings
education_mapping = {
    'Üniversite mezunu': 'university graduate',
    'Yüksek lisans/Doktora': "master's degree/PhD holder",
    'Lise mezunu': "high-school graduate",
    'İlköğretim/Ortaokul mezunu': "secondary school graduate",
    'İlkokul mezunu': "primary school graduate",
    'Diplomasız okur': "literate but nongraduate",
    np.nan: ""
}
df_survey_data['Eğitim_EN'] = df_survey_data['Eğitim'].map(education_mapping)

# 3) Map ethnicity to desired strings
ethnicity_mapping = {
    'Türk': 'Turkish',
    'Kürt': 'Kurdish',
    'Türk,Kürt': 'Turkish and Kurdish',
    'Türk,Zaza': 'Turkish and Zaza',
    'Türk,Diğer': 'partly Turkish',
    'Arap': 'Arab',
    'Diğer': "",
    np.nan: ""
}
df_survey_data['Etnisite_EN'] = df_survey_data['Etnisite'].map(ethnicity_mapping)

# 4) Map city codes to city names
df_survey_data['Şehir_EN'] = df_survey_data['Şehir'].map(city_mapping)

# %%
# Display the first few rows of the survey data
df_survey_data[['username', 'Age_EN', 'Eğitim_EN', 'Etnisite_EN', 'Şehir_EN']].head()
# Out:
#         username  Age_EN                   Eğitim_EN Etnisite_EN   Şehir_EN
# 0        otisabi      59         university graduate     Turkish      Muğla
# 1  drcihanyilmaz      37  master's degree/PhD holder     Turkish     Manisa
# 2           arda       0        high-school graduate     Turkish  Çanakkale
# 3     fridakahlo      33  master's degree/PhD holder     Turkish     Ankara
# 4  dilekozcengiz      62  master's degree/PhD holder     Turkish      Adana

# %%
# Calculate the percentage of NaN values in 'location_x'
nan_count = df_survey_data['location_x'].isna().sum()
total_rows = df_survey_data.shape[0]
nan_percentage = (nan_count / total_rows) * 100
print(f"Percentage of NaN values in 'location_x': {nan_percentage:.2f}%")
# Out:
# Percentage of NaN values in 'location_x': 70.46%

# %%
# Sample supporters
supporters_kemal = df_survey_data[df_survey_data['CB 2. Tur'] == 'Kemal Kılıçdaroğlu']
print(f"Total number of Kemal Kılıçdaroğlu supporters: {len(supporters_kemal)}")
sample_kemal = supporters_kemal.sample(n=SAMPLE_SIZE, random_state=RANDOM_STATE)
supporters_erdogan = df_survey_data[df_survey_data['CB 2. Tur'] == 'Recep Tayyip Erdoğan']
print(f"Total number of Recep Tayyip Erdoğan supporters: {len(supporters_erdogan)}")
# Out:
# Total number of Kemal Kılıçdaroğlu supporters: 797
# Total number of Recep Tayyip Erdoğan supporters: 91

# %%
sample_erdogan = supporters_erdogan.sample(n=SAMPLE_SIZE, random_state=RANDOM_STATE)
combined_samples = pd.concat([sample_kemal, sample_erdogan], ignore_index=True)
print(f"Total samples we picked: {len(combined_samples)}")
# Out:
# Total samples we picked: 180

# %%
# Display the usernames and their selected candidate
combined_samples[['username', 'CB 2. Tur']]
# Out:
#          username             CB 2. Tur
# 0        coscosgg    Kemal Kılıçdaroğlu
# 1     zbayzdemir1    Kemal Kılıçdaroğlu
# 2    halilaltinay    Kemal Kılıçdaroğlu
# 3        ucurtmam    Kemal Kılıçdaroğlu
# 4          suvuck    Kemal Kılıçdaroğlu
# ..            ...                   ...
# 175   zekiserttas  Recep Tayyip Erdoğan
# 176    hamzaatunc  Recep Tayyip Erdoğan
# 177     paptya727  Recep Tayyip Erdoğan
# 178     mstfhayri  Recep Tayyip Erdoğan
# 179     zehros357  Recep Tayyip Erdoğan
#
# [180 rows x 2 columns]

# %%
# Load tweets data
with open('tweets_data.json', 'r', encoding='utf-8') as file:
    tweets_data = json.load(file)
print("Tweets data loaded successfully.")
# Out:
# Tweets data loaded successfully.

# %%
MODEL_NAME = "gpt-4o-2024-05-13"
openai_api_key = os.getenv('OPENAI_API_KEY')

# Initialize OpenAI client
client = OpenAI(api_key=openai_api_key)

# %%
def analyze_tweets_with_prompts(username, user_tweets, row):
    """Analyze tweets using three different prompts and return the responses."""
    tweets_text = "\n".join(tweet["text"] for tweet in user_tweets[:70])

    prompt1 = (
        f"I am {row['Age_EN']} years old, a {row['Eğitim_EN']}, of {row['Etnisite_EN']} ethnicity, "
        f"and I identify as {row['gender_survey']}. I live in {row['Şehir_EN']}. "
        f"In the second round of the 2023 Turkish presidential elections, between Kemal Kılıçdaroğlu and Recep Tayyip Erdoğan, "
        f"whom did I vote for? Please respond with either 'Kılıçdaroğlu' or 'Erdoğan'."
    )

    prompt2 = (
        f"I am {row['Age_EN']} years old, a {row['Eğitim_EN']}, of {row['Etnisite_EN']} ethnicity, "
        f"and I identify as {row['gender_survey']}. I live in {row['Şehir_EN']}. Here are some of my tweets: "
        f"'''{tweets_text}'''. Based on this information, in the second round of the 2023 Turkish presidential elections, "
        f"between Kemal Kılıçdaroğlu and Recep Tayyip Erdoğan, whom did I vote for? Please respond with either 'Kılıçdaroğlu' or 'Erdoğan'."
    )

    prompt3 = (
        f"Here are some of my tweets: '''{tweets_text}'''. Based on my tweets, in the second round of the 2023 Turkish presidential elections, "
        f"between Kemal Kılıçdaroğlu and Recep Tayyip Erdoğan, whom did I vote for? Please respond with either 'Kılıçdaroğlu' or 'Erdoğan'."
    )

    prompts = [prompt1, prompt2, prompt3]
    results = []

    for prompt in prompts:
        try:
            completion = client.chat.completions.create(
                model=MODEL_NAME,
                messages=[
                    {"role": "system", "content": "You are a political analysis assistant. Analyze the tweets and return only the name of one of the two listed candidates."},
                    {"role": "user", "content": prompt},
                ],
            )
            results.append(completion.choices[0].message.content)
        except Exception as e:
            print(f"An error occurred for user {username} with prompt: {prompt[:30]}... : {str(e)}")
            results.append("Error")

    return results

# %%
# Analyze tweets and collect results for each prompt
all_results = {}
response_dict = {}

for index, row in combined_samples.iterrows():
    username = row['username']
    if username in tweets_data:
        user_tweets = tweets_data[username]
        candidate_responses = analyze_tweets_with_prompts(username, user_tweets, row)
        all_results[username] = candidate_responses
        response_dict[username] = {
            "prompt1": candidate_responses[0],
            "prompt2": candidate_responses[1],
            "prompt3": candidate_responses[2]
        }
        print(f"{username} -> prompt1: {candidate_responses[0]}, prompt2: {candidate_responses[1]}, prompt3: {candidate_responses[2]}")
    else:
        print(f"No tweets found for user: {username}")
# Out:
# coscosgg -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# zbayzdemir1 -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# halilaltinay -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# ucurtmam -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# suvuck -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# kahwedelisi -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# yesimozn -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# muuguney -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Kılıçdaroğlu
# cidominko -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# lutfiduran3 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# sitivingerrard -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# chatdenoir1 -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# emekorh -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Kılıçdaroğlu
# bircelicious -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# omercakir31 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# moondialmi -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# tamortadangel -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# mertaliavc -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# ylcn31 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# eyllbng -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# tu_ylmz -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# missyuksel -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# karabulutylmz -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# seherdemkoc -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: I’m sorry, but with the information provided, I can't determine whom you voted for in the 2023 Turkish presidential elections.
# su_sebnem -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# semraalkan6 -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# acarmob -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# bayrakliseval -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# akujinnn1 -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Kılıçdaroğlu
# kodaknihat -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# buyasemin -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# nurr_nurr -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# ayseboren1 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# ismetgencerr -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# netgolgo -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# meri_g35 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# secilyabenli -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Without the content of the tweets, I cannot determine whom you voted for. If you provide the tweets, I can analyze them to identify your preference.
# vanteluzia -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# talatcemalenver -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# mesudeak -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# dilekiran -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# procekts34 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# mmsigin -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# sennnem -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# nazimsaglam -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# busraarkan_ -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# denizcemsahin -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# y_emresecinti -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# ozalpsenay -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# kaosihbar -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# albatrosati -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# rehber_20 -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# poyrazli -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Kılıçdaroğlu
# alatay00007375 -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# tanerotti44 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# mevaaa_ -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# u_task -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# dr_zeynepyilmaz -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# aranizdanbirkiz -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Erdoğan
# dumanbey18 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# muhalif_dede -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# cf4thew -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# cekilsurdan_ -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Erdoğan
# fatmaadali -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# mhayirsiz3418 -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# serhaterkin -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# orhanou51841202 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# oguzmustafa -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: I can't determine which candidate you supported without more information or analysis of your tweets. Could you provide content or more context from your tweets for accurate analysis?
# fusunneksi -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# aphasiainstrume -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# mhrmkystl -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# omergurler1960 -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# aliozcllk -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: I'm sorry, but there is no information provided in your message for me to analyze and determine your voting choice. Could you provide more context or content from your tweets?
# adnanserpen -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# ercan006 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# fasc1nati0n -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# edatuzcuuu -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# mnrdn -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# psifel -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# memeenjoyer2 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Sorry, I can't determine which candidate you voted for based on this information.
# mehmetaliglpna2 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# ersengulenc -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# hasanergene -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# maun35 -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# dilarak_ra -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# deniz44eylul -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Kılıçdaroğlu
# yaslimarti -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: I'm sorry, but without the content of the tweets, I'm unable to determine whom you voted for. Please provide the content of the tweets for analysis.
# sheriffs_k -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# kadirceceli -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Kılıçdaroğlu
# mustafadogru_ -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# n1943_ -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# ilhamiacun -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# mervehasar6 -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# samisatan -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: I'm sorry, but I need more context or content from your tweets to provide an analysis. Could you please provide some of your tweets?
# jkmentality -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Erdoğan
# saniyeatabey -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# emine -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: I'm sorry, but based on the provided tweet, I cannot determine whether you voted for Kemal Kılıçdaroğlu or Recep Tayyip Erdoğan.
# cevdetyilmaz -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Erdoğan
# ivazerkan -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# acerciz -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# kunasmile -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# ibrahimtylgl -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# zeynepaktay -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: I'm sorry, but based on the information provided, I'm unable to determine who you voted for. There were no tweets for me to analyze.
# berkuist -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# fahrettinaltun_ -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# ugurerdem_ -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# korayankara89 -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# ugurbesiktas55 -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# cemsahbaz -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# furkantamirci -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# sanane -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: I'm sorry, but I can't determine whom you voted for based on the information provided.
# taspinarisa -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# farukpaluluoglu -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: I apologize, but I can't determine who you voted for based on the provided tweets, because the input appears to be empty. Could you provide some of the actual tweets or more context?
# bhczr -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# nursemuhammed -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# drannee -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# dindarcihaner -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Kılıçdaroğlu
# selamikamiloglu -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# drcenkyilmaz -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# beyazrenkler -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: I'm sorry, but I need to see the content of your tweets to determine your voting preference. Could you please provide the text of your tweets?
# eneyasemen -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# sedsu -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# theseyda_7418 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# ozlemyarenn -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# sbyenimol -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# sahafhakki -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# melikeisbored -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# gumrukcuoglu61 -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# granieve -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# eelmasssudee -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# neslihanyslgl -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# kurtmemet68 -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# guser1r -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# sineemly -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# mufmetin -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# nurullahcoskun -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# hasangenc -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# pptyaaz -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# yigidim19 -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# inceselahattin -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# aemek38 -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# glamdring2004 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# ahmetesenler -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# hseyninar12125 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# mah_dum -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# karakaya_x -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# ayfer02156519 -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# alikara1905 -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# dtzeynepguven -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# enginmeral20 -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# jexistediyorum -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# savasbuyuk -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# bedirhan80 -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Kılıçdaroğlu
# hafi2e -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# suayipsanay -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: I'm sorry, but I can't provide an analysis or make a determination based on the information given.
# mhrmsln -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# ustuncansav -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# cihansahiin -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# sewurt -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# makarachi -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# emak -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Erdoğan
# yesimborek -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# ikraozgn -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: I'm sorry, but there is no content in the provided tweets for me to analyze. Could you please provide some actual tweets for me to review?
# coolmanyas -> prompt1: Erdoğan, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# mungan06 -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# bordovira61 -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# bi_merdumgirizz -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# tilmiz_ -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# adilhazar -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# rtnhbo -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# zubeydekosker -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# alim_albayrak -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# bahareyn -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# kusayer -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# mkkorkmazz61 -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# zekiserttas -> prompt1: Erdoğan, prompt2: Erdoğan, prompt3: Erdoğan
# hamzaatunc -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# paptya727 -> prompt1: Kılıçdaroğlu, prompt2: Erdoğan, prompt3: Erdoğan
# mstfhayri -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu
# zehros357 -> prompt1: Kılıçdaroğlu, prompt2: Kılıçdaroğlu, prompt3: Kılıçdaroğlu

# %%
# Save results to a JSON file
timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
file_name = f"results_{MODEL_NAME}_{timestamp}.json"
with open(file_name, "w", encoding='utf-8') as f:
    json.dump(response_dict, f, indent=4, ensure_ascii=False)
print(f"Results saved to {file_name}.")
# Out:
# Results saved to results_gpt-4o-2024-05-13_20240519155949.json.
